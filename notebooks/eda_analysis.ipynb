# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# %%
sys.path.append(os.path.abspath('../scripts'))

# %%
df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|')
# Out:
# C:\Users\ftesfaye\AppData\Local\Temp\ipykernel_24664\1487130439.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|')

# %%
print(df.dtypes)
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
from eda_fun import (calculate_descriptive_statistics,inspect_data_types,check_missing_values,plot_categorical_distributions,
                     plot_numerical_distributions,plot_correlation,compare_trends_by_geography,detect_outliers,
                     plot_heatmap,premium_distribution_by_covertype,claims_trend_over_time,identify_column_types)

# %%
summary_statistics = calculate_descriptive_statistics(df)
print(summary_statistics)
# Out:
#        TotalPremium   TotalClaims  CalculatedPremiumPerTerm    SumInsured
# count  1.000098e+06  1.000098e+06              1.000098e+06  1.000098e+06
# mean   6.190550e+01  6.486119e+01              1.178757e+02  6.041727e+05
# std    2.302845e+02  2.384075e+03              3.997017e+02  1.508332e+06
# min   -7.825768e+02 -1.200241e+04              0.000000e+00  1.000000e-02
# 25%    0.000000e+00  0.000000e+00              3.224800e+00  5.000000e+03
# 50%    2.178333e+00  0.000000e+00              8.436900e+00  7.500000e+03
# 75%    2.192982e+01  0.000000e+00              9.000000e+01  2.500000e+05
# max    6.528260e+04  3.930921e+05              7.442217e+04  1.263620e+07

# %%
# We'll check for any missing values in the dataset.
missing_values = check_missing_values(df)
print(missing_values)
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
# histograms for numerical columns and bar charts for categorical columns.
plot_numerical_distributions(df)

# %%
plot_categorical_distributions(df)

# %%
# Correlations between TotalPremium, TotalClaims, and ZipCode
plot_correlation(df)

# %%
# Trends by ZipCode
compare_trends_by_geography(df)
# Out:
# c:\Users\ftesfaye\Desktop\KIFIYA\New folder\kifiya_week_3\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Box Plot for Outlier Detection
detect_outliers(df)

# %%
# 3 Creative and Beautiful Plots
plot_heatmap(df)
premium_distribution_by_covertype(df)
claims_trend_over_time(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 plot_heatmap(df)
#       3 premium_distribution_by_covertype(df)
# ----> 4 claims_trend_over_time(df)
#
# File c:\Users\ftesfaye\Desktop\KIFIYA\New folder\kifiya_week_3\scripts\eda_fun.py:104, in claims_trend_over_time(df)
#     103 def claims_trend_over_time(df):
# --> 104     df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])
#     105     monthly_claims = df.groupby(['TransactionMonth', 'CoverType']).agg({'TotalClaims': 'sum'}).reset_index()
#     107     plt.figure(figsize=(10, 6))
#
# NameError: name 'pd' is not defined

# %%
from eda_fun import clean_data,save_cleaned_data_csv

# %%
df_cleaned = clean_data(df)
print(df_cleaned.info())
# Out:
# c:\Users\ftesfaye\Desktop\KIFIYA\New folder\kifiya_week_3\scripts\eda_fun.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[numerical_cols] = df_cleaned[numerical_cols].fillna(df_cleaned[numerical_cols].median())
# c:\Users\ftesfaye\Desktop\KIFIYA\New folder\kifiya_week_3\scripts\eda_fun.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[categorical_cols] = df_cleaned[categorical_cols].fillna(df_cleaned[categorical_cols].mode().iloc[0])
# ...

# %%
# Call the function
save_cleaned_data_csv(df_cleaned, '../data/cleaned_data.csv')
