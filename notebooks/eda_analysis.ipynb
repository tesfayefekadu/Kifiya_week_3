# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# %%
sys.path.append(os.path.abspath('../scripts'))

# %%
df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|')
# Out:
# C:\Users\ftesfaye\AppData\Local\Temp\ipykernel_24968\1487130439.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|')

# %%
from eda_fun import (calculate_descriptive_statistics,inspect_data_types,check_missing_values,plot_numerical_distributions,
                     plot_categorical_distributions,plot_correlation,compare_trends_by_geography,detect_outliers,
                     plot_heatmap,premium_distribution_by_covertype,claims_trend_over_time,identify_column_types)

# %%
summary_statistics = calculate_descriptive_statistics(df)
print(summary_statistics)
# Out:
#        TotalPremium   TotalClaims  CalculatedPremiumPerTerm    SumInsured
# count  1.000098e+06  1.000098e+06              1.000098e+06  1.000098e+06
# mean   6.190550e+01  6.486119e+01              1.178757e+02  6.041727e+05
# std    2.302845e+02  2.384075e+03              3.997017e+02  1.508332e+06
# min   -7.825768e+02 -1.200241e+04              0.000000e+00  1.000000e-02
# 25%    0.000000e+00  0.000000e+00              3.224800e+00  5.000000e+03
# 50%    2.178333e+00  0.000000e+00              8.436900e+00  7.500000e+03
# 75%    2.192982e+01  0.000000e+00              9.000000e+01  2.500000e+05
# max    6.528260e+04  3.930921e+05              7.442217e+04  1.263620e+07

# %%
# data types
data_types = inspect_data_types(df)
print(data_types)
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# bodytype                     object
# NumberOfDoors               float64
# VehicleIntroDate             object
# CustomValueEstimate         float64
# AlarmImmobiliser             object
# TrackingDevice               object
# CapitalOutstanding           object
# NewVehicle                   object
# WrittenOff                   object
# Rebuilt                      object
# Converted                    object
# CrossBorder                  object
# NumberOfVehiclesInFleet     float64
# SumInsured                  float64
# TermFrequency                object
# CalculatedPremiumPerTerm    float64
# ExcessSelected               object
# CoverCategory                object
# CoverType                    object
# CoverGroup                   object
# Section                      object
# Product                      object
# StatutoryClass               object
# StatutoryRiskType            object
# TotalPremium                float64
# TotalClaims                 float64
# dtype: object

# %%
# We'll check for any missing values in the dataset.
missing_values = check_missing_values(df)
print(missing_values)
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# bodytype                        552
# NumberOfDoors                   552
# VehicleIntroDate                552
# CustomValueEstimate          779642
# AlarmImmobiliser                  0
# TrackingDevice                    0
# CapitalOutstanding                2
# NewVehicle                   153295
# WrittenOff                   641901
# Rebuilt                      641901
# Converted                    641901
# CrossBorder                  999400
# NumberOfVehiclesInFleet     1000098
# SumInsured                        0
# TermFrequency                     0
# CalculatedPremiumPerTerm          0
# ExcessSelected                    0
# CoverCategory                     0
# CoverType                         0
# CoverGroup                        0
# Section                           0
# Product                           0
# StatutoryClass                    0
# StatutoryRiskType                 0
# TotalPremium                      0
# TotalClaims                       0
# dtype: int64

# %%
# histograms for numerical columns and bar charts for categorical columns.
plot_numerical_distributions(df)

# %%
plot_categorical_distributions(df)

# %%
# Correlations between TotalPremium, TotalClaims, and ZipCode
plot_correlation(df)

# %%
# Trends by ZipCode
compare_trends_by_geography(df)

# %%
# Box Plot for Outlier Detection
detect_outliers(df)

# %%
# 3 Creative and Beautiful Plots
plot_heatmap(df)
premium_distribution_by_covertype(df)
claims_trend_over_time(df)
